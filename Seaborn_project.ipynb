# %%
Project:
------------------------------
1.Restaurant Tips Data Analysis with Seaborn

Objective:
-----------------------------------------
Restaurant dataset analyze karna (total bill, tips, gender, day, time, etc.) 
aur data ko Seaborn plots se visualize karna.

# %%
#Import libraries

import seaborn as sns
import matplotlib.pyplot as plt

# import datasets - 

df=sns.load_dataset('Tips')
#print(df)
print(df.columns)
print(df.head())
print(df.info())

# ========================================================
# Distribution of total bills using histogram plot - 
# ========================================================

plt.figure(figsize=(7,4))
sns.histplot(df['total_bill'],bins=20,color='purple')
plt.xlabel('Total bill')
plt.ylabel('Freguency')
plt.title("Distribution of total bill")
plt.show()

# =======================================================
# Relationship: Total_bill vs tip using scatter plot
# =======================================================
plt.figure(figsize=(7,4))
sns.scatterplot(x='total_bill',y='tip',color='red',hue='sex',style='smoker',data=df)
plt.title("Total_Bill vs Tip (by Gender & Smoker)")
plt.show()

# ========================================================
# Boxplot : Tips by day 
# ========================================================

plt.figure(figsize=(7,4))
sns.boxplot(x='day',y='tip',data=df, hue='day', palette ='Set2')
plt.title("Tips by day")
plt.show()

# =======================================================
# Correlation heatmap 
# =======================================================

plt.figure(figsize=(8,5))
corr=df.corr(numeric_only=True)
sns.heatmap (corr,annot=True,cmap="coolwarm")
plt.title( "Correlation heatmap")
plt.show()

#====================================================
# Pairplot relation
# ====================================================

sns.pairplot(df,palette='husl',hue='sex')
plt.show()
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# None
